# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
ns = pd.read_excel('naversub.xlsx')
ns.set_index("date", inplace=True)

# %%
ns = pd.read_excel('naversub.xlsx')

# %%
df = pd.read_excel('datalab.xlsx')

# %%
ns
# Out:
#             search count
# date
# 2019-01-01       9.69485
# 2019-01-02      11.81820
# 2019-01-03      11.71616
# 2019-01-04      12.93977
# 2019-01-05      12.21749
# ...                  ...
# 2022-11-16      20.45093
# 2022-11-17      17.38790
# 2022-11-18      21.64792
# 2022-11-19      17.62837
# 2022-11-20      13.57421
#
# [1420 rows x 1 columns]

# %%
# %matplotlib inline

# %%
plt.figure(figsize=(16,12))
ns.plot( )
plt.show()

# %%
df.plot(x='date',y='search count', color = 'gray', figsize=(8,5))
plt.show()
